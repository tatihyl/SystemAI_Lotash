# %% [markdown]
# # Практическая работа №1

# %% [markdown]
# ## Тема: "Основные возможности языка Python"

# %% [markdown]
# ### Выполнил студент: Лоташ Антон

# %% [markdown]
# #### ВАРИАНТ:14

# %% [markdown]
# Задание 1. Расчеты арифметических выражений

# %% [markdown]
# УСЛОВИЕ: $z=2+(\frac{\frac{5+a}{y}}{\frac{3a}{x-a}})a + \frac{2x+5x-3a}{8x+3a}+12x$

# %% [markdown]
# x=float(input('Введите х '))
# y=float(input('Введите у '))
# a=float(input('Введите а '))
# z=2+(((5+a)/y)/(((3*a)/(x-a))))*a+(2*x+5*x-3*a)/(8*x+3*a)+2*y
# print('z= ',z)

# %% [markdown]
# #### Задание 2.  Расчеты математических выражений

# %% [markdown]
# #### УСЛОВИЕ: $z=\frac{\sin^2(x)+y}{y+1}-\frac{xy-12}{34+x^2}$

# %%
import math

x=float(input('Введите х '))
y=float(input('Введите у '))
z=(math.sin(x)*math.sin(x)+y)/(y+1)-(x*y-12)/(34+x*x)
print("z= ", z)
# Out:
# Введите х  1
# Введите у  1
# z=  1.1683224234224998

# %% [markdown]
# #### Задание 3. Логические вычисления

# %% [markdown]
# #### УСЛОВИЕ: ![image.png](attachment:f9feb890-3a73-482b-bafe-2c6f7353fcbe.png)

# %%
x=float(input('Введите х '))
y=float(input('Введите у '))
if x>=3 and x<=5 and y>=3 and y<=7:
    print('находится')
elif x>=6 and x<=9 and y>=5 and y<= 11:
    print('находится')
elif x==9 and y>=3 and y<=4:
    print('находится') 
elif x == 10 and y>=3 and y<=8:
    print('находится')
elif x>=11 and x<=12 and y == 3:
    print('находится')
elif x>=11 and x<=13 and y>=6 and y<= 8:
    print('находится')
elif x>=3 and x<=12 and y == 11:
    print('находится')
elif x>=7 and x<= 12 and y == 12:
    print('находится')
elif x>=9 and x<=10 and y == 13:
    print('находится')
else:
    print('Не находится')
# Out:
# Введите х  1
# Введите у  1
# Не находится

# %% [markdown]
# #### Задание 4. Логические вычисления

# %% [markdown]
# #### УСЛОВИЕ: ![image.png](attachment:2e0ffb68-e238-401d-9f07-e74086a97b60.png)

# %%
x=float(input('Введите х '))
y=float(input('Введите у '))
if y <= x and x >= 0 and x*x+y*y<=1:
    print('Да')
elif y >= -x and x*x+y*y<=1:
    print('Да')
else:
    print('нет')
# Out:
# Введите х  0
# Введите у  0.2
# Да

# %% [markdown]
# #### Задание 5.Вычисление циклических процессов

# %% [markdown]
# #### УСЛОВИЕ: $f(x)=\frac{2+\cos^2(x+1)}{1+|x-\frac{3x}{1+x^2}|}+x$

# %%
import math
print('Введите значение переменных')
print('Введите начальное значение Х1:')
X1 = int(input())
print('Введите начальное значение Х2:')
X2 = int(input())
print('Введите шаг S:')
S = float(input())
print('**************************************************************')
print('РЕЗУЛЬТАТ:')
print('+----------------+')
print('|  X  |   f(x)   |')
print('+----------------+')
while (X1 <= X2):
    Y = (2+math.cos(X1+1)**2)/(1+math.fabs(X1-3*X1/(1+X1**2)))+X1
    print('|{:5.2f}|{:10.2f}|'.format(X1, Y))
    X1 = X1 + S
print('+----------------+')
print('**************************************************************')
# Out:
# Введите значение переменных
# Введите начальное значение Х1:
#  100
# Введите начальное значение Х2:
#  110
# Введите шаг S:
#  1
# **************************************************************
# РЕЗУЛЬТАТ:
# +----------------+
# |  X  |   f(x)   |
# +----------------+
# |100.00|    100.03|
# |101.00|    101.02|
# |102.00|    102.03|
# |103.00|    103.03|
# |104.00|    104.02|
# |105.00|    105.02|
# |106.00|    106.03|
# |107.00|    107.02|
# |108.00|    108.02|
# |109.00|    109.03|
# |110.00|    110.02|
# +----------------+
# **************************************************************

# %% [markdown]
# #### Задание 6.Списки(одномерные массивы) в Python

# %% [markdown]
# #### УСЛОВИЕ:Дан целочисленный одномерный массив на N элементов, заполненный случайными числами в заданном диапазоне (от n1 до n2) с чередованием через два значения произведением двух предыдущих значений. Найти произведение значений из его элементов с четными номерами от K до L включительно. Произвести проверку на корректность ввода значений (n1<n2).

# %%
import random
n1 = 0
n2 = 0
N = 0
def check(n1,n2,N):
    print('Введите количество элементов в массиве:')
    N = int(input())
    print('***************************************************************************************************************************')
    print('ВВЕДИТЕ ДИАПАЗОН ЗНАЧЕНИЙ')
    print('Введите начало диапазона случайных чисел, которыми заполнится массив, n1:')
    n1 = int(input())
    print('Введите конец диапазона случайных чисел, которыми заполнится массив, n2:')
    n2 = int(input())
    print('***************************************************************************************************************************')
    return next(n1,n2,N)
def next(n1,n2,N):   
    if (n1<n2):
        arr = []
        for i in range(N):
            arr.append(random.randint(n1,n2))
        for i in range(N):
            if(i%3==2):
                arr.pop(i)
                arr.insert(i, arr[i-2]*arr[i-1])
        print('Сгенерированный одномерный массив')
        for i in range(N):
            print('{} ) {}'.format(i, arr[i]))
        print('***************************************************************************************************************************')
        print('Введите К')
        K = int(input())
        print('Введите L')
        L = int(input())
        print('***************************************************************************************************************************')
        result = 1
        for i in range(N):
            if(i%2==0 and i>=K and i<=L):
                print('{} ) {}'.format(i, arr[i]))
                result = result*arr[i]
        print('***************************************************************************************************************************')
        print('Произведение четных элементов массива = ',result)
    else:
        print('Некорректный ввод данных! n1>=n2\nПопробуйте ввести корректные значения ')
        check(n1,n2,N)
check(n1,n2,N)
# Out:
# Введите количество элементов в массиве:
#  10
# ***************************************************************************************************************************
# ВВЕДИТЕ ДИАПАЗОН ЗНАЧЕНИЙ
# Введите начало диапазона случайных чисел, которыми заполнится массив, n1:
#  -10
# Введите конец диапазона случайных чисел, которыми заполнится массив, n2:
#  10
# ***************************************************************************************************************************
# Сгенерированный одномерный массив
# 0 ) 4
# 1 ) -3
# 2 ) -12
# 3 ) 7
# 4 ) -8
# 5 ) -56
# 6 ) -6
# 7 ) -6
# 8 ) 36
# 9 ) 6
# ***************************************************************************************************************************
# Введите К
#  2
# Введите L
#  5
# ***************************************************************************************************************************
# 2 ) -12
# 4 ) -8
# ...

# %% [markdown]
# #### Задание 7. Двумерные массивы (матрицы) в Python

# %% [markdown]
# #### УСЛОВИЕ: Дан целочисленный двумерный массив N на M элементов, заполненный случайными числами в заданном диапазоне (от n1 до n2) с чередованием через два значения произведением двух предыдущих значений в строках. Найти произведение значений из его элементов с чётными номерами от K до L включительно в заданном столбце С. Произвести проверку на корректность ввода значений (n1<n2, K<L, С и т.д.).

# %%
import random
import pandas as pd
n1 = 0
n2 = 0
N = 0
M = 0
C = 0
def check(n1,n2,N,M):
    print('Введите количество строк N в массиве:')
    N = int(input())
    print('Введите количество столбцов M в массиве:')
    M = int(input())
    print('***************************************************************************************************************************')
    print('ВВЕДИТЕ ДИАПАЗОН ЗНАЧЕНИЙ')
    print('Введите начало диапазона случайных чисел, которыми заполнится массив, n1:')
    n1 = int(input())
    print('Введите конец диапазона случайных чисел, которыми заполнится массив, n2:')
    n2 = int(input())
    print('***************************************************************************************************************************')
    return next(n1,n2,N,M)
def next(n1,n2,N,M):   
    if (n1<n2):
        arr = [ [0]*M for i in range(N) ]
        for i in range(N):
            for j in range(M):
                arr[i][j] = (random.randint(n1,n2))     
        for i in range(N):
            for j in range(M):
                if (j%3==2):
                    arr[i][j] = arr[i][j-2]*arr[i][j-1]  
        print('Сгенерированный двумерный массив')
        print(pd.DataFrame(arr))
        print('***************************************************************************************************************************')
        choose(N,M,K,L,C,arr)
    else:
        print('Некорректный ввод данных! n1>=n2\nПопробуйте ввести корректные значения ')
        check(n1,n2,N,M,arr)
def choose(N,M,K,L,C,arr):
        print('Введите К')
        K = int(input())
        print('Введите L')
        L = int(input())
        if(K<L):
           lastchoose(N,M,K,L,C,arr)
        else:
            print('Некорректный ввод данных! K>=L\nПопробуйте ввести корректные значения ')
            choose(N,M,K,L,C,arr)
def lastchoose(N,M,K,L,C,arr):
    print('Введите С')
    C = int(input())
    if(C<0 or C>M):
        print('Некорректный ввод данных! C<0 или C>M\nПопробуйте ввести корректные значения ')
        lastchoose(N,M,K,L,C,arr)
    else:
        print('***************************************************************************************************************************')
        result = 1
        for i in range(N):
            for j in range(M):
                if(i%2==0 and i>=K and i<=L and j==C):
                    print('{} ) {}'.format(i, arr[i][j]))
                    result = result*arr[i][j]
        print('***************************************************************************************************************************')
        print('Произведение четный элементов массива в столбце ',C,' = ',result)
check(n1,n2,N,M)
# Out:
# Введите количество строк N в массиве:
#  6
# Введите количество столбцов M в массиве:
#  6
# ***************************************************************************************************************************
# ВВЕДИТЕ ДИАПАЗОН ЗНАЧЕНИЙ
# Введите начало диапазона случайных чисел, которыми заполнится массив, n1:
#  1
# Введите конец диапазона случайных чисел, которыми заполнится массив, n2:
#  5
# ***************************************************************************************************************************
# Сгенерированный двумерный массив
#    0  1   2  3  4   5
# 0  4  2   8  5  1   5
# 1  1  3   3  3  2   6
# 2  3  1   3  4  2   8
# 3  1  3   3  2  2   4
# 4  5  2  10  1  5   5
# 5  2  3   6  5  2  10
# ***************************************************************************************************************************
# Введите К
#  2
# Введите L
#  6
# Введите С
#  3
# ...
